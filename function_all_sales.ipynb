# %%
import csv
import pandas as pd

# %%
dataset = pd.read_csv('UnitSummary__P1D__table-chart.csv', delimiter=';')
dataset
# Out:
#      Unnamed: 0      Период                        Пиццерия  Выручка  \
# 0           431  2025-06-16  Железногорск Курской области-1    68396
# 1           413  2025-06-17            Троицк Челябинская-1   141552
# 2           258  2025-06-01            Троицк Челябинская-1   295916
# 3           363  2025-06-13  Железногорск Курской области-1   221184
# 4           370  2025-06-12  Железногорск Курской области-1   216136
# ..          ...         ...                             ...      ...
# 427         305  2025-06-15                         Курск-3   261658
# 428         306  2025-06-10                         Курск-2   260342
# 429         331  2025-06-03                  Магнитогорск-1   242697
# 430         257  2025-06-07             Санкт-Петербург 3-3   298629
# 431         369  2025-06-02  Железногорск Курской области-1   217192
#
#      Выручка, доставка  Выручка ресторан + самовывоз  \
# 0                65435                          2961
# ...
